# %%
##downloading data from gdrive

# %%
import gdown
url="https://drive.google.com/file/d/12pIdF8Lk6i_qLUxw07_9is_6t57P4iEX/view?usp=drive_link"

# %%
file_id=url.split("/")[-2]

# %%
prefix="https://drive.google.com/uc?export=download&id"
gdown.download(prefix+file_id,"dataset.zip")
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id12pIdF8Lk6i_qLUxw07_9is_6t57P4iEX
# To: c:\Users\Lenovo\Desktop\deeplearn-1\MLOPs-Production-Ready-Deep-Learning-Project\research\dataset.zip
# 1.70kB [00:00, 718kB/s]
# 'dataset.zip'
